# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/shreeyadaga/Documents/college/Sem6/DSBDA/DSBDALExam DataSets/DSBDALExam DataSets/dataset_Facebook.csv',
                delimiter=';');
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.dropna(axis=0, how='any', inplace=True)
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
Photo = df[df['Type'] == 'Photo']
Status = df[df['Type'] == 'Status']
Link = df[df['Type'] == 'Link']

Photo.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
Link.head()
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
Status.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
merged = pd.concat([Status, Link],ignore_index=True)
merged
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441  Status         2          12             3         10
# 1             139441  Status         2          12             1          9
# 2             139441  Status         2          12             7          3
# 3             139441  Status         2          12             5         10
# 4             138414  Status         2          12             3         10
# ..               ...     ...       ...         ...           ...        ...
# 62             91437    Link         1           2             3         13
# 63             86909    Link         1           1             6          4
# 64             86491    Link         1           1             4          4
# 65             86491    Link         1           1             2          2
# 66             85979    Link         1           1             5         11
#
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
sort_likes = df.sort_values(by='Page total likes', ascending=True,ignore_index=True)
sort_likes
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               81370   Photo         3           1             4         11
# 1               81370   Photo         1           1             5          2
# 2               81370   Photo         2           1             5          8
# 3               85093   Photo         3           1             1          2
# 4               85093   Photo         3           1             7          2
# ..                ...     ...       ...         ...           ...        ...
# 490            139441  Status         2          12             5         10
# 491            139441   Photo         2          12             5         10
# 492            139441   Photo         2          12             5          3
# 493            139441   Photo         3          12             7          9
# 494            139441   Photo         2          12             4          3
#
# ...

# %%
transpose = df.transpose()
transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
melted_df  = pd.melt(df, id_vars = ['Type'],var_name='Measurement', value_name='value')
melted_df
# Out:
#         Type         Measurement     value
# 0      Photo    Page total likes  139441.0
# 1     Status    Page total likes  139441.0
# 2      Photo    Page total likes  139441.0
# 3      Photo    Page total likes  139441.0
# 4      Photo    Page total likes  139441.0
# ...      ...                 ...       ...
# 8905   Photo  Total Interactions     176.0
# 8906   Photo  Total Interactions      84.0
# 8907   Photo  Total Interactions      75.0
# 8908   Photo  Total Interactions     115.0
# 8909   Photo  Total Interactions     136.0
#
# [8910 rows x 3 columns]

# %%
melted_value_df  = pd.melt(df, id_vars = ['Type'],value_vars = ['comment','like','share'] ,var_name='Measurement', value_name='value')
melted_value_df
# Out:
#         Type Measurement  value
# 0      Photo     comment    4.0
# 1     Status     comment    5.0
# 2      Photo     comment    0.0
# 3      Photo     comment   58.0
# 4      Photo     comment   19.0
# ...      ...         ...    ...
# 1480   Photo       share   41.0
# 1481   Photo       share   26.0
# 1482   Photo       share   22.0
# 1483   Photo       share   18.0
# 1484   Photo       share   38.0
#
# [1485 rows x 3 columns]

# %%
casted_df = melted_df.pivot_table(index='Type', columns='Measurement',values='value')
casted_df
# Out:
# Measurement    comment        like      share
# Type
# Link          2.818182   73.318182  12.909091
# Photo         7.581948  184.066508  27.156770
# Status        8.911111  176.711111  31.422222
# Video        12.285714  231.428571  52.142857

# %%
casted_value_df = melted_value_df.pivot_table(index='Type',columns='Measurement',values='value').reset_index()
casted_value_df
# Out:
# Measurement    Type    comment        like      share
# 0              Link   2.818182   73.318182  12.909091
# 1             Photo   7.581948  184.066508  27.156770
# 2            Status   8.911111  176.711111  31.422222
# 3             Video  12.285714  231.428571  52.142857

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
df_reset = df.reset_index().rename(columns={'index':'id'})
df_reset
# Out:
#       id  Page total likes    Type  Category  Post Month  Post Weekday  \
# 0      0            139441   Photo         2          12             4
# 1      1            139441  Status         2          12             3
# 2      2            139441   Photo         3          12             3
# 3      3            139441   Photo         2          12             2
# 4      4            139441   Photo         2          12             2
# ..   ...               ...     ...       ...         ...           ...
# 490  494             85093   Photo         3           1             7
# 491  495             85093   Photo         3           1             7
# 492  496             81370   Photo         2           1             5
# 493  497             81370   Photo         1           1             5
# 494  498             81370   Photo         3           1             4
#
#      Post Hour  Paid  Lifetime Post Total Reach  \
# 0            3   0.0                       2752
# ...

# %%
melted_reset_df = pd.melt(df_reset, id_vars=['id','Type'],var_name='measurement',value_name='value')
melted_reset_df
# Out:
#        id    Type         measurement     value
# 0       0   Photo    Page total likes  139441.0
# 1       1  Status    Page total likes  139441.0
# 2       2   Photo    Page total likes  139441.0
# 3       3   Photo    Page total likes  139441.0
# 4       4   Photo    Page total likes  139441.0
# ...   ...     ...                 ...       ...
# 8905  494   Photo  Total Interactions     176.0
# 8906  495   Photo  Total Interactions      84.0
# 8907  496   Photo  Total Interactions      75.0
# 8908  497   Photo  Total Interactions     115.0
# 8909  498   Photo  Total Interactions     136.0
#
# [8910 rows x 4 columns]

# %%
casted_reset_df = melted_reset_df.pivot(index='id', values='value',columns='measurement').reset_index()
casted_reset_df
# Out:
# measurement   id  Category  Lifetime Engaged Users  \
# 0              0       2.0                   178.0
# 1              1       2.0                  1457.0
# 2              2       3.0                   177.0
# 3              3       2.0                  2211.0
# 4              4       2.0                   671.0
# ..           ...       ...                     ...
# 490          494       3.0                   810.0
# 491          495       3.0                   733.0
# 492          496       2.0                   537.0
# 493          497       1.0                   625.0
# 494          498       3.0                   626.0
#
# measurement  Lifetime People who have liked your Page and engaged with your post  \
# 0                                                        119.0
# 1                                                       1108.0
# 2                                                        132.0
# 3                                                       1386.0
# ...
